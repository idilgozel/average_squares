# %%
average_of_squares([2, 4], [1, 0.5])
# Out:
# 12.0

# %%
average_of_squares([1, 2, 4], [1, 0.5])
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 average_of_squares([1, 2, 4], [1, 0.5])
#
# File ~/average_squares/squares.py:22, in average_of_squares(list_of_numbers, list_of_weights)
#       5 """ Return the weighted average of a list of values.
#       6
#       7 By default, all values are equally weighted, but this can be changed
#    (...)     19
#      20 """
#      21 if list_of_weights is not None:
# ---> 22     assert len(list_of_weights) == len(list_of_numbers), \
#      23         "weights and numbers must have same length"
#      24     effective_weights = list_of_weights
#      25 else:
#
# AssertionError: weights and numbers must have same length

# %%
# %%bash
# python -m doctest squares.py
# Out:
# **********************************************************************
# File "/Users/idilgozel/average_squares/squares.py", line 12, in squares.average_of_squares
# Failed example:
#     average_of_squares([1, 2, 4])
# Exception raised:
#     Traceback (most recent call last):
#       File "/opt/anaconda3/envs/physics-env/lib/python3.11/doctest.py", line 1355, in __run
#         exec(compile(example.source, filename, "single",
#       File "<doctest squares.average_of_squares[0]>", line 1, in <module>
#         average_of_squares([1, 2, 4])
#     TypeError: average_of_squares() missing 1 required positional argument: 'list_of_weights'
# **********************************************************************
# File "/Users/idilgozel/average_squares/squares.py", line 14, in squares.average_of_squares
# Failed example:
#     average_of_squares([2, 4], [1, 0.5])
# Expected:
#     4.0
# Got:
#     6.0
# **********************************************************************
# File "/Users/idilgozel/average_squares/squares.py", line 43, in squares.convert_numbers
# Failed example:
#     convert_numbers(["4", " 8 ", "15 16", " 23    42 "])
# Expected:
#     [4, 8, 15, 16]
# Got:
#     [4.0, 8.0, 15.0, 16.0, 23.0, 42.0]
# **********************************************************************
# 2 items had failures:
#    2 of   3 in squares.average_of_squares
#    1 of   1 in squares.convert_numbers
# ***Test Failed*** 3 failures.
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 get_ipython().run_cell_magic('bash', '', 'python -m doctest squares.py\n')
#
# File /opt/anaconda3/envs/physics-env/lib/python3.11/site-packages/IPython/core/interactiveshell.py:2565, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2563 with self.builtin_trap:
#    2564     args = (magic_arg_s, cell)
# -> 2565     result = fn(*args, **kwargs)
#    2567 # The code below prevents the output from being displayed
#    2568 # when using magics with decorator @output_can_be_silenced
#    2569 # when the last Python token in the expression is a ';'.
#    2570 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File /opt/anaconda3/envs/physics-env/lib/python3.11/site-packages/IPython/core/magics/script.py:160, in ScriptMagics._make_script_magic.<locals>.named_script_magic(line, cell)
#     158 else:
#     159     line = script
# --> 160 return self.shebang(line, cell)
#
# File /opt/anaconda3/envs/physics-env/lib/python3.11/site-packages/IPython/core/magics/script.py:348, in ScriptMagics.shebang(self, line, cell)
#     343 if args.raise_error and p.returncode != 0:
#     344     # If we get here and p.returncode is still None, we must have
#     345     # killed it but not yet seen its return code. We don't wait for it,
#     346     # in case it's stuck in uninterruptible sleep. -9 = SIGKILL
#     347     rc = p.returncode or -9
# --> 348     raise CalledProcessError(rc, cell)
#
# CalledProcessError: Command 'b'python -m doctest squares.py\n'' returned non-zero exit status 1.

# %%
import squares
from squares import average_of_squares

# %%
average_of_squares([1, 2, 4])
# Out:
# 21

# %%
average_of_squares([2, 4], [1, 0.5])
# Out:
# 12.0
